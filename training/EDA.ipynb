# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path_data = 'dataset/n1_n2_n3_cleaned/'

# %%
df_anodic_1 = pd.read_csv(f'{path_data}anodic_N1.csv')
df_cathodic_1 = pd.read_csv(f'{path_data}cathodic_N1.csv')
df_corrosion_1 = pd.read_csv(f'{path_data}corrosion_N1.csv')

df_anodic_2 = pd.read_csv(f'{path_data}anodic_N2.csv')
df_cathodic_2 = pd.read_csv(f'{path_data}cathodic_N2.csv')
df_corrosion_2 = pd.read_csv(f'{path_data}corrosion_N2.csv')

df_anodic_3 = pd.read_csv(f'{path_data}anodic_N3.csv')
df_cathodic_3 = pd.read_csv(f'{path_data}cathodic_N3.csv')
df_corrosion_3 = pd.read_csv(f'{path_data}corrosion_N3.csv')

# %%
df_n1_combined = pd.concat([df_anodic_1, df_cathodic_1, df_corrosion_1], axis=0, ignore_index=True)

df_n2_combined = pd.concat([df_anodic_2, df_cathodic_2, df_corrosion_2], axis=0, ignore_index=True)

df_n3_combined = pd.concat([df_anodic_3,df_cathodic_3,df_corrosion_3], axis=0, ignore_index=True)

# %%
df_combined = pd.concat([df_anodic_1, df_cathodic_1, df_corrosion_1,df_anodic_2, df_cathodic_2, df_corrosion_2,df_anodic_3,df_cathodic_3,df_corrosion_3], axis=0, ignore_index=True)
df_combined.shape
# Out:
# (1586116, 5)

# %%
numeric_cols = ['accoustic_emmision_data', 'electrochemical_data',
       'mechanical_data']

# %% [markdown]
# ## N1 Data Visualization

# %%
num_plots = 3
num_cols = 2  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(numeric_cols):
    sns.histplot(df_n1_combined[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
num_plots = 3
num_cols = 2  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing
col_comb = [['accoustic_emmision_data', 'electrochemical_data'],['accoustic_emmision_data','mechanical_data'],['electrochemical_data','mechanical_data']]
for i, col in enumerate(col_comb):
    sns.scatterplot(data=df_n1_combined,x=col_comb[i][0],y=col_comb[i][1], hue='output',ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=df_n1_combined,
                x='accoustic_emmision_data',
                y='electrochemical_data',
                hue='output',
                palette='pastel',
                s=100)
plt.show()

# %%
df_n1_combined.output.value_counts()
# Out:
# output
# anodic       190568
# corrosion    137620
# cathodic     136749
# Name: count, dtype: int64

# %%
sns.scatterplot(data=df_n1_combined,
                x='accoustic_emmision_data',
                y='mechanical_data',
                hue='output',
                palette='pastel',
                s=100)
plt.show()

# %%
sns.scatterplot(data=df_n1_combined,
                x='electrochemical_data',
                y='mechanical_data',
                hue='output',
                palette='pastel',
                s=100)
plt.show()

# %% [markdown]
# ### N2 Data Visulization

# %%
num_plots = 3
num_cols = 2  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(numeric_cols):
    sns.histplot(df_n2_combined[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
num_plots = 3
num_cols = 2  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing
col_comb = [['accoustic_emmision_data', 'electrochemical_data'],['accoustic_emmision_data','mechanical_data'],['electrochemical_data','mechanical_data']]
for i, col in enumerate(col_comb):
    sns.scatterplot(data=df_n2_combined,x=col_comb[i][0],y=col_comb[i][1], hue='output',ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### N3 Data Visualization

# %%
num_plots = 3
num_cols = 2  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(numeric_cols):
    sns.histplot(df_n3_combined[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
num_plots = 3
num_cols = 2  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing
col_comb = [['accoustic_emmision_data', 'electrochemical_data'],['accoustic_emmision_data','mechanical_data'],['electrochemical_data','mechanical_data']]
for i, col in enumerate(col_comb):
    sns.scatterplot(data=df_n3_combined,x=col_comb[i][0],y=col_comb[i][1], hue='output',ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
